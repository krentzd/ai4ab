# %% [markdown]
# # Results on K. pneumoniae brightfield data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from utils import DataLoader, ResultsPlotter

# %%
loader = DataLoader(params_dir='K_pneumoniae_params', species='K_pneumoniae')
loader.load_files(['BF'], [1, 2, 3, 4])
plotter = ResultsPlotter(loader)

# %%
ch = 'BF'
r = 1
d = 3
d_name = '1xIC50'
ch_name = 'Brightfield'
plotter.plot_cond_confusion_matrix(d, ch, r,
                                   save_name=f'cond_cmpd_conf_matrix_klebsiella_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                   save=True, 
                                   title=f'{ch_name} ({d_name})',
                                   title_fontsize=20, tick_fontsize=16, label_fontsize=16)

# %%
ch = 'BF'
r = 1
d = 3
d_name = '1xIC50'
ch_name = 'Brightfield'
plotter.plot_cond_moa_confusion_matrix(d, ch, r, 
                                       save_name=f'cond_moa_conf_matrix_klebsiella_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                       save=True, 
                                       title=f'{ch_name} ({d_name})',
                                       title_fontsize=20, tick_fontsize=16, label_fontsize=16, label_name='MoA')
