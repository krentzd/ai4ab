# %% [markdown]
# ## Confusion matrices

# %%
from utils import DataLoader, ResultsPlotter

# %%
loader = DataLoader()
loader.load_files(['BF', 'Hoechst_FM4_BF'], [1, 2, 3, 4])
plotter = ResultsPlotter(loader)

# %%
ch = 'BF'
r = 2
d = 4
d_name = '1xIC50'
ch_name = 'Brightfield'
plotter.plot_cond_confusion_matrix(d, ch, r,
                                   save_name=f'cond_cmpd_conf_matrix_e_coli_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                   save=True, 
                                   title=f'{ch_name} ({d_name})',
                                   title_fontsize=20, tick_fontsize=16, label_fontsize=16)
# Out:
# /home/daniel/Documents/MANUSCRIPTS/AI4AB Paper/CODE/ai4ab/analysis/utils.py:200: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + classes_true, rotation=90, fontsize=tick_fontsize)
# /home/daniel/Documents/MANUSCRIPTS/AI4AB Paper/CODE/ai4ab/analysis/utils.py:201: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + classes_pred, fontsize=tick_fontsize)
# Saving to cond_cmpd_conf_matrix_e_coli_dose_1xIC50_BF_rep_3.svg

# %%
ch = 'BF'
r = 2
d = 4
d_name = '1xIC50'
ch_name = 'Brightfield'
plotter.plot_cond_moa_confusion_matrix(d, ch, r, 
                                       save_name=f'cond_moa_conf_matrix_e_coli_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                       save=True, 
                                       title=f'{ch_name} ({d_name})',
                                       title_fontsize=20, tick_fontsize=16, label_fontsize=16, label_name='MoA')
# Out:
# {'Cell wall (PBP 1)': 1, 'Cell wall (PBP 2)': 2, 'Cell wall (PBP 3)': 3, 'Control': 0, 'DNA synthesis': 7, 'Gyrase': 5, 'Membrane integrity': 8, 'RNA polymerase': 6, 'Ribosome': 4}
# Saving to cond_moa_conf_matrix_e_coli_dose_1xIC50_BF_rep_3.svg

# %%
ch = 'Hoechst_FM4_BF'
r = 2
d = 4
d_name = '1xIC50'
ch_name = ch.replace('_', '+')
plotter.plot_cond_confusion_matrix(d, ch, r,
                                   save_name=f'cond_cmpd_conf_matrix_e_coli_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                   save=True, 
                                   title=f'{ch_name} ({d_name})',
                                   title_fontsize=20, tick_fontsize=16, label_fontsize=16)
# Out:
# Saving to cond_cmpd_conf_matrix_e_coli_dose_1xIC50_Hoechst_FM4_BF_rep_3.svg

# %%
ch = 'Hoechst_FM4_BF'
r = 2
d = 4
d_name = '1xIC50'
ch_name = ch.replace('_', '+')
plotter.plot_cond_moa_confusion_matrix(d, ch, r, 
                                       save_name=f'cond_moa_conf_matrix_e_coli_dose_{d_name}_{ch}_rep_{r+1}.svg', 
                                       save=True, 
                                       title=f'{ch_name} ({d_name})',
                                       title_fontsize=20, tick_fontsize=16, label_fontsize=16, label_name='MoA')
# Out:
# {'Cell wall (PBP 1)': 1, 'Cell wall (PBP 2)': 2, 'Cell wall (PBP 3)': 3, 'Control': 0, 'DNA synthesis': 7, 'Gyrase': 5, 'Membrane integrity': 8, 'RNA polymerase': 6, 'Ribosome': 4}
# Saving to cond_moa_conf_matrix_e_coli_dose_1xIC50_Hoechst_FM4_BF_rep_3.svg

# %% [markdown]
# ## UMAP plots

# %%
loader = DataLoader()
loader.load_files(['Hoechst_FM4_BF'], [3])
plotter = ResultsPlotter(loader)

# %%
plotter.plot_umap(title='E. coli by compound',
                  save_name='umap_e_coli_by_cmpd.svg')

# %%
plotter.plot_umap(title='E. coli by MoA',
                  save_name='umap_e_coli_by_cmpd.svg',
                  use_moa_labels=True)

# %% [markdown]
# ## Cosine similarity matrices

# %%
plotter.plot_cosine_similarity_matrix(title='Cosine similarity of feature vectors',
                                      save_name='cosine_similarity_e_coli.svg')

# %%
loader = DataLoader()
loader.load_files(['BF'], [3])
plotter = ResultsPlotter(loader)
plotter.plot_cosine_similarity_matrix(title='Cosine similarity of feature vectors (BF)',
                                      save_name='cosine_similarity_e_coli_bf.svg')

# %% [markdown]
# ## Cross validation plots by channel

# %%
loader = DataLoader()
loader.load_files(['BF', 'FM4', 'Hoechst', 'FM4_BF', 'Hoechst_BF', 'Hoechst_FM4', 'Hoechst_FM4_BF'], [1,2,3,4])
plotter = ResultsPlotter(loader)

# %%
plotter.plot_channel_accuracies()
# Out:
# ['BF', 'FM4', 'Hoechst', 'FM4 + BF', 'Hoechst + BF', 'Hoechst + FM4', 'Hoechst + FM4 + BF']
# /home/daniel/Documents/MANUSCRIPTS/AI4AB Paper/CODE/ai4ab/analysis/utils.py:637: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([ch.replace('_', '\n') for ch in ch_name_list_non_confo], fontsize=9)

# %%
plotter.plot_channel_accuracies(use_moa_labels=True)
# Out:
# ['BF', 'FM4', 'Hoechst', 'FM4 + BF', 'Hoechst + BF', 'Hoechst + FM4', 'Hoechst + FM4 + BF']
# /home/daniel/Documents/MANUSCRIPTS/AI4AB Paper/CODE/ai4ab/analysis/utils.py:637: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([ch.replace('_', '\n') for ch in ch_name_list_non_confo], fontsize=9)

# %% [markdown]
# ## UMAP by dose

# %%
loader = DataLoader()
loader.load_files(['BF'], [3])
plotter = ResultsPlotter(loader)

# %%
plotter.plot_umap_by_dose(save_name='cmpd_embeddings_e_coli_dose.svg')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
plotter.plot_umap_by_dose(save_name='moa_embeddings_e_coli_dose.svg',
                          use_moa_labels=True)

# %% [markdown]
# ## Drug exposure detection

# %%
from utils import DataLoader, ResultsPlotter

# %%
loader = DataLoader()
loader.load_files(['BF'], [1,2,3,4])

# %%
plotter = ResultsPlotter(loader)

# %%
plotter.plot_drug_exposure_detection(plate=2)

# %%
plotter.plot_roc_curve()

# %% [markdown]
# ## Data subsampling plot

# %%
from utils import SubsamplingDataLoader, SubsamplingPlotter, plot_num_images

# %%
loader = SubsamplingDataLoader()
loader.load_files(pretrained=True)
plotter = SubsamplingPlotter(loader)

# %%
plotter.plot_curve_fit()

# %%
plotter.plot_plateau()

# %%
loader2 = SubsamplingDataLoader()
loader2.load_files(pretrained=False)
plotter2 = SubsamplingPlotter(loader2)

# %%
plot_num_images(plotter, plotter2)
# Out:
# /home/daniel/Documents/MANUSCRIPTS/AI4AB Paper/CODE/ai4ab/analysis/utils.py:855: RuntimeWarning: invalid value encountered in divide
#   idx_list = self.index([self.plate_id, self.subsample_id, self.mic_id], [[plate], [sub], [0, dose]])
