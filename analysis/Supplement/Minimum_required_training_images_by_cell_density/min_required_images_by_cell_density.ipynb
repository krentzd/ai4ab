# %% [markdown]
# # Influence of cell density on required training image counts

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from plotting import get_accuracy_dicts, plot_curve_fit, plot_min_num_images

# %%
mean_acc, std_acc = get_accuracy_dicts()

# %%
plot_curve_fit(mean_acc, std_acc)

# %%
plot_min_num_images(mean_acc, std_acc)
