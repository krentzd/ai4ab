# %% [markdown]
# # E. coli model applied to K. pneumoniae data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from plotting import cluster_feat_vecs

# %%
cluster_feat_vecs(dose='1xIC50')
