# %% [markdown]
# # HZI Replication Experiment

# %%
from plotting import Plotter

# %%
plotter = Plotter(dose='1xIC50')

# %%
plotter.plot_compound_confusion_matrix()

# %%
plotter.plot_moa_confusion_matrix()

# %%
plotter.plot_moa_accuracy()

# %%
plotter = Plotter(dose='2xIC50')

# %%
plotter.plot_compound_confusion_matrix()

# %%
plotter.plot_moa_confusion_matrix()

# %%
plotter.plot_moa_accuracy()
