# %% [markdown]
# # Benchmarking different training settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from plotting import get_acc_dicts, plot_accuracies

# %%
moa_acc_dict, moa_max_acc_dict = get_acc_dicts()

# %%
plot_accuracies(moa_acc_dict, title='MoA classification\naccuracy by FOV (1xIC50)')

# %%
plot_accuracies(moa_max_acc_dict, title='MoA classification\naccuracy by well (1xIC50)', save_name='moa_acc_by_well_benchmarking.svg')
